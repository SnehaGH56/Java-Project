# %%
import pandas as pd
# Step 1: Collect data from a CSV file
file_path = "C:\Users\Sneha biswas\Downloads\CS2225 Datasets for lab-20250808T040927Z-1-001\CS2225 Datasets for lab/Program1_E-Commerce Reviews.csv"
try:
    df = pd.read_csv(file_path)
    print("Original Data:\n", df.head())
except FileNotFoundError:
    print(f"Error: File '{file_path}' not found. Please check the file path.")
    exit(1)
except pd.errors.EmptyDataError:
    print(f"Error: The file '{file_path}' is empty or invalid.")
    exit(1)
except Exception as e:
    print(f"Error reading CSV file: {e}")
    exit(1)
